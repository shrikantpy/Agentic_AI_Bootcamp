# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # List practice

# %% [markdown]
# ### Enter a ***TO-DO*** list

# %% [markdown]
# * Enter a TO-DO list to manage tasks

# %%
to_do_list = [
    "Learn Pandas",
    "Practice NumPy",
    "Create Visualizations with Matplotlib",
    "Explore Seaborn"
]

# %%
# Adding a new task to the to-do list
to_do_list.append("Build a Data Science Project")

#Adding another task
to_do_list.append("Study Machine Learning Algorithms")

print("To-Do List:")
for task in to_do_list:
    print(f"- {task}")

# Remove a completed task
to_do_list.remove("Practice NumPy")
print("\nUpdated To-Do List:")
for task in to_do_list:
    print(f"- {task}")

# Check a task in the to-do list
task_to_check = "Learn Pandas"
if task_to_check in to_do_list:
    print(f"\nDon't forget to complete the task: '{task_to_check}'")
else:
    print(f"\nGood job! You have completed the task: '{task_to_check}'")
# Out:
# To-Do List:
# - Learn Pandas
# - Practice NumPy
# - Create Visualizations with Matplotlib
# - Explore Seaborn
# - Build a Data Science Project
# - Study Machine Learning Algorithms
#
# Updated To-Do List:
# - Learn Pandas
# - Create Visualizations with Matplotlib
# - Explore Seaborn
# - Build a Data Science Project
# - Study Machine Learning Algorithms
#
# Don't forget to complete the task: 'Learn Pandas'

# %%
grades = [85, 92, 78, 90, 88]
average_grade = np.mean(grades)
print(f"\nAverage Grade: {average_grade}")

# Adding a new grade
grades.append(95)
new_average_grade = np.mean(grades)
print(f"New Average Grade after adding 95: {new_average_grade}")

#finding highest and lowest grades
highest_grade = np.max(grades)
lowest_grade = np.min(grades)
print(f"Highest Grade: {highest_grade}")
print(f"Lowest Grade: {lowest_grade}")
# Out:
# Average Grade: 86.6
# New Average Grade after adding 95: 88.0
# Highest Grade: 95
# Lowest Grade: 78

# %% [markdown]
# # Sets

# %% [markdown]
# ## What is a Set in Python?
#
# A set in Python is an unordered collection of unique elements. It is mutable, meaning you can add or remove elements after creation, but the elements themselves must be immutable (e.g., numbers, strings, tuples).
#
# ### Key Features:
# - **Unordered**: Elements do not have a specific order.
# - **Unique**: No duplicate elements are allowed.
# - **Mutable**: You can modify the set by adding or removing elements.
# - **No Indexing**: You cannot access elements by index like in lists.
#
# ### Creating a Set:

# %%
my_set = set()
print(f"\ntype of my_set: {type(my_set)}")
print(f"Initial my_set: {my_set}")
# Out:
# type of my_set: <class 'set'>
# Initial my_set: set()

# %%
# Adding a new element to the set
my_set.add("apple")
print(f"my_set after adding 'apple': {my_set}")
# Out:
# my_set after adding 'apple': {'apple'}

# %%
my_set.add("banana")
my_set.add("orange")
my_set.add("apple")  # Duplicate, won't be added
my_set.add("grape")
my_set.remove("banana")
my_set.discard("kiwi")  # No error if not present
print(f"Final my_set: {my_set}")
# my_set.remove("kiwi")  # This will raise a KeyError if "kiwi" is not present
# Out:
# Final my_set: {'grape', 'apple', 'orange'}

# %%
removed_element = my_set.pop()
print(f"my_set after popping an element: {my_set}")
print(f"Popped element: {removed_element}")
# Out:
# my_set after popping an element: {'grape', 'orange'}
# Popped element: apple

# %%
# Membership test
element_to_check = "orange"
if element_to_check in my_set:
    print(f"{element_to_check} is present in the set.")
else:
    print(f"{element_to_check} is not present in the set.")

element_to_check = "banana"
if element_to_check in my_set:
    print(f"{element_to_check} is present in the set.")
else:
    print(f"{element_to_check} is not present in the set.")
# Out:
# orange is present in the set.
# banana is not present in the set.

# %%
# Mathematical set operations
set_a = {"apple", "banana", "cherry"}
set_b = {"banana", "dragonfruit", "elderberry"}
union_set = set_a.union(set_b)
intersection_set = set_a.intersection(set_b)
difference_set = set_a.difference(set_b)
print(f"Union of set_a and set_b: {union_set}")
print(f"Intersection of set_a and set_b: {intersection_set}")
print(f"Difference of set_a and set_b: {difference_set}")
# Out:
# Union of set_a and set_b: {'dragonfruit', 'apple', 'elderberry', 'cherry', 'banana'}
# Intersection of set_a and set_b: {'banana'}
# Difference of set_a and set_b: {'apple', 'cherry'}

# %%
set_a.intersection_update(set_b)
print(f"set_a after intersection_update with set_b: {set_a}")
# Out:
# set_a after intersection_update with set_b: {'banana'}

# %%
# Symmetric difference
symmetric_difference_set = set_a.symmetric_difference(set_b)
print(f"Symmetric difference of set_a and set_b: {symmetric_difference_set}")
# Out:
# Symmetric difference of set_a and set_b: {'dragonfruit', 'elderberry', 'cherry', 'apple'}

# %%
# Set methods summary
# add(), remove(), discard(), pop(), clear(), union(), intersection(), difference(), symmetric_difference()

print(set_a.issubset(set_b))
print(set_b.issuperset(set_a))
# Out:
# False
# False

# %%
lst1 = [1, 2, 3, 4, 5, 6, 5,5, 4, 7,3, 4]
set(lst1)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
# Counting unique words in a list
test_text = "This is a test text with several words. This text is for testing unique word count."
words = test_text.split()
unique_words = set(words)
unique_word_count = len(unique_words)
print(f"Unique words: {unique_words}")
print(f"Number of unique words: {unique_word_count}")
# Out:
# Unique words: {'text', 'with', 'several', 'a', 'words.', 'is', 'count.', 'for', 'testing', 'This', 'word', 'test', 'unique'}
# Number of unique words: 13

# %% [markdown]
# # Dictionary

# %% [markdown]
# ## What is a Dictionary in Python?
#
# A dictionary in Python is a mutable, unordered collection of key-value pairs. It allows you to store and retrieve data efficiently using unique keys instead of indices like lists.
#
# ### Key Features:
# - **Keys**: Must be immutable (e.g., strings, numbers, tuples). Keys are unique within a dictionary.
# - **Values**: Can be any data type, including lists, other dictionaries, etc.
# - **Mutable**: You can add, remove, or modify key-value pairs after creation.
# - **Unordered**: Items do not have a specific order (though in Python 3.7+, insertion order is preserved).
#
# ### Creating a Dictionary:
# ```python
# # Empty dictionary
# my_dict = {}
#
# # Dictionary with initial values
# student = {"name": "Alice", "age": 25, "courses": ["Math", "Science"]}
# ```
#
# ### Accessing Values:
# Use square brackets with the key:
# ```python
# print(student["name"])  # Output: Alice
# ```
#
# ### Common Operations:
# - Add/Update: `student["grade"] = "A"`
# - Remove: `del student["age"]`
# - Check existence: `"name" in student`
# - Get all keys: `student.keys()`
# - Get all values: `student.values()`
# - Get key-value pairs: `student.items()`
#
# Dictionaries are powerful for mapping relationships and are widely used in Python for data manipulation and configuration.

# %%
# Defining an emmpty dictionary
# There are two common ways to define an empty dictionary in Python:

# Method 1: Using curly braces {}
empty_dict = {}
print(f"Empty dictionary using curly braces: {empty_dict}")
print(f"type of empty_dict using curly braces: {type(empty_dict)}")

# Method 2: Using the dict() constructor
empty_dict = dict()
print(f"Empty dictionary using dict(): {empty_dict}")
print(f"type of empty_dict using dict(): {type(empty_dict)}")
# Out:
# Empty dictionary using curly braces: {}
# type of empty_dict using curly braces: <class 'dict'>
# Empty dictionary using dict(): {}
# type of empty_dict using dict(): <class 'dict'>

# %%
student = {"Name": "John", "Age": 21, "Courses": ["Math", "CompSci"], "GPA": 4.2}
print(f"Student Dictionary: {student}")
print(f"Name: {student['Name']}")
print(f"Age: {student['Age']}")
print(f"Courses: {student['Courses']}")
print(f"GPA: {student['GPA']}")
# Out:
# Student Dictionary: {'Name': 'John', 'Age': 21, 'Courses': ['Math', 'CompSci'], 'GPA': 4.2}
# Name: John
# Age: 21
# Courses: ['Math', 'CompSci']
# GPA: 4.2

# %%
# Repeated keys in dictionaries silently overwrite values, which can lead to data loss. Always ensure keys are unique.
# Example:
test = {"Name": "Shrikant", "Subject": ["Maths, Science"], "Grade": "A", "Subject": "Computer"}
print(test)
# Out:
# {'Name': 'Shrikant', 'Subject': 'Computer', 'Grade': 'A'}

# %%
# Accessing dictionary elements:
student = {"Name": "John", "Age": 21, "Courses": ["Math", "CompSci"], "GPA": 4.2}
print(f"Student grade is: {student["GPA"]}")
print(f"Student age is : {student['Age']}")
# Out:
# Student grade is: 4.2
# Student age is : 21

# %%
# Accessing dictionary values using get() method:
print(student.get("Name"))
print(student.get("Address", "Address not found"))  # Default value if key doesn't exist
print(student.get("Course"))  # None if key doesn't exist
print(student.get("Courses"))
print(student.get("Courses")[0]) # Accessing first course
# Out:
# John
# Address not found
# None
# ['Math', 'CompSci']
# Math

# %%
# Modifying dictionary elements
# Modifying existing key name is not possible, but we can achieve it by adding a new key with the desired name and deleting the old key.
student = {"Name": "John", "Age": 21, "Courses": ["Math", "CompSci"], "GPA": 4.2}
student["Age"] = 22  # Modifying existing key value
student["Major"] = "Computer Science"  # Adding a new key-value pair
del student["GPA"]  # Deleting a key-value pair
student["Courses"] = ["Math", "CompSci", "Physics"]  # Modifying the list of courses
student["Courses"].append("Biology")  # Adding a new course to the list
print(f"Modified Student Dictionary: {student}")
# Out:
# Modified Student Dictionary: {'Name': 'John', 'Age': 22, 'Courses': ['Math', 'CompSci', 'Physics', 'Biology'], 'Major': 'Computer Science'}

# %%
# useful dictionary methods
# keys(), values(), items(), update(), pop(), popitem(), clear(), copy()
keys = list(student.keys())
print(f"Dictionary Keys: {keys}")
values = list(student.values())
print(f"Dictionary Values: {values}")
items = list(student.items())
print(f"Dictionary Items: {items}")
# Out:
# Dictionary Keys: ['Name', 'Age', 'Courses', 'Major']
# Dictionary Values: ['John', 22, ['Math', 'CompSci', 'Physics', 'Biology'], 'Computer Science']
# Dictionary Items: [('Name', 'John'), ('Age', 22), ('Courses', ['Math', 'CompSci', 'Physics', 'Biology']), ('Major', 'Computer Science')]

# %%
# Shallow copy
original_dict = {"Name": "Alice", "Age": 25, "Courses": ["Math", "Physics"]}
shallow_copied_dict = original_dict.copy()  # Shallow copy
copy_of_original_dict = original_dict
copy_of_original_dict["Age"] = 26
copy_of_original_dict["Courses"].append("Chemistry")

print(f"Original Dictionary: {original_dict}")
print(f"Copy of Original Dictionary: {copy_of_original_dict}")
print(f"Shallow Copied Dictionary: {shallow_copied_dict}")
# Out:
# Original Dictionary: {'Name': 'Alice', 'Age': 26, 'Courses': ['Math', 'Physics', 'Chemistry']}
# Copy of Original Dictionary: {'Name': 'Alice', 'Age': 26, 'Courses': ['Math', 'Physics', 'Chemistry']}
# Shallow Copied Dictionary: {'Name': 'Alice', 'Age': 25, 'Courses': ['Math', 'Physics', 'Chemistry']}

# %%
# Iterating through a dictionary
student = {"Name": "John", "Age": 21, "Courses": ["Math", "CompSci"], "GPA": 4.2}

# Iterating through keys
for key in student:
    print("Keys:")
    print(f"{key}: {student[key]}")

# Through values
for value in student.values():
    print("Values:")
    print(value)

# Through key-value pairs
print("Key-Value Pairs:")
for key, value in student.items():
    print(f"{key}: {value}")
# Out:
# Keys:
# Name: John
# Keys:
# Age: 21
# Keys:
# Courses: ['Math', 'CompSci']
# Keys:
# GPA: 4.2
# Values:
# John
# Values:
# 21
# Values:
# ['Math', 'CompSci']
# Values:
# 4.2
# Key-Value Pairs:
# Name: John
# Age: 21
# Courses: ['Math', 'CompSci']
# GPA: 4.2

# %%
# Nested dictionaries
students = {
    "student1": {"Name": "John", "Age": 21, "Courses": ["Math", "CompSci"]},
    "student2": {"Name": "Jane", "Age": 22, "Courses": ["Biology", "Chemistry"]},
    "student3": {"Name": "Mike", "Age": 20, "Courses": ["History", "English"]}
}

print(f"Students Dictionary: {students}")

# Accessing nested dictionary elements
print(f"Student1 Name: {students['student1']['Name']}")
print(f"Student2 Courses: {students['student2']['Courses']}")
# Out:
# Students Dictionary: {'student1': {'Name': 'John', 'Age': 21, 'Courses': ['Math', 'CompSci']}, 'student2': {'Name': 'Jane', 'Age': 22, 'Courses': ['Biology', 'Chemistry']}, 'student3': {'Name': 'Mike', 'Age': 20, 'Courses': ['History', 'English']}}
# Student1 Name: John
# Student2 Courses: ['Biology', 'Chemistry']

# %%
# Iterating through a nested dictionary
for student_id, student_info in students.items():
    print(f"\n{student_id}:")
    for key, value in student_info.items():
        print(f"  {key}: {value}")
# Out:
# student1:
#   Name: John
#   Age: 21
#   Courses: ['Math', 'CompSci']
#
# student2:
#   Name: Jane
#   Age: 22
#   Courses: ['Biology', 'Chemistry']
#
# student3:
#   Name: Mike
#   Age: 20
#   Courses: ['History', 'English']

# %%
# Dictionary comprehension
squares = {str(x): x**2 for x in range(1, 11)}
print(f"Squares Dictionary: {squares}")
# Out:
# Squares Dictionary: {'1': 1, '2': 4, '3': 9, '4': 16, '5': 25, '6': 36, '7': 49, '8': 64, '9': 81, '10': 100}

# %%
# Conditional dictionary comprehension
even_squares = {str(x): x**2 for x in range(1, 11) if x % 2 == 0}
print(f"Even Squares Dictionary: {even_squares}")
# Out:
# Even Squares Dictionary: {'2': 4, '4': 16, '6': 36, '8': 64, '10': 100}

# %%
# Practical example:
# Use a dictionary to count the frequency of each word in a given text.
text = "This is a sample text with several words. This text is for testing word frequency"
word_count = {}
words = text.split()
for word in words:    
    word = word.lower().strip(".,")  # Normalize the word
    if word in word_count:
        word_count[word] += 1
    else:
        word_count[word] = 1

print(f"Word Frequency: {word_count}")
# Out:
# Word Frequency: {'this': 2, 'is': 2, 'a': 1, 'sample': 1, 'text': 2, 'with': 1, 'several': 1, 'words': 1, 'for': 1, 'testing': 1, 'word': 1, 'frequency': 1}

# %%
# Use a dictionary to count the frequency of elements in a list.
elements = [1, 2, 2, 3, 4, 4, 4, 5, 1, 2, 3, 5, 5, 6, 7, 8, 8, 9, 10, 10, 10]
element_count = {}
for element in elements:
    if element in element_count:
        element_count[element] += 1
    else:
        element_count[element] = 1
print(f"Element Frequency: {element_count}")
# Out:
# Element Frequency: {1: 2, 2: 3, 3: 2, 4: 3, 5: 3, 6: 1, 7: 1, 8: 2, 9: 1, 10: 3}

# %%
# Merge two dictionaries representing student grades from different subjects into a single dictionary.
grades_subject1 = {"Alice": 85, "Bob": 90, "Charlie": 78}
grades_subject2 = {"Alice": 88, "Bob": 92, "David": 80}
merged_grades = grades_subject1.copy()  # Start with grades from subject 1
merged_grades.update(grades_subject2)   # Update with grades from subject 2
print(f"Merged Grades: {merged_grades}")
# Out:
# Merged Grades: {'Alice': 88, 'Bob': 92, 'Charlie': 78, 'David': 80}

# %%
# Merge two dictionaries representing student grades from different subjects into a single dictionary.
grades_subject1 = {"Alice": 85, "Bob": 90, "Charlie": 78}
grades_subject2 = {"Alice": 88, "Bob": 92, "David": 80}
merged_grades = {**grades_subject1, **grades_subject2}  # Merging using dictionary unpacking
print(f"Merged Grades: {merged_grades}")
# Out:
# Merged Grades: {'Alice': 88, 'Bob': 92, 'Charlie': 78, 'David': 80}
